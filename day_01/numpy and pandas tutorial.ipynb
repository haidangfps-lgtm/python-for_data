# %%
from random import random

import pandas as pd

# %%
import numpy as np

# %%
data = np.array([[1,4], [2,5], [3,6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
example = pd.DataFrame(data, index=['row1','row2','row3'], columns=['col1','col2'])

# %%
example
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
states = ['usa', 'thanh hoa', 'france', 'vietnam']

# %%
population = [10000, 20000, 30000 ,40000]

# %%
dictionary = {'State':states, 'Population':population}

# %%
example2 = pd.DataFrame(dictionary)

# %%
example2
# Out:
#        State  Population
# 0        usa       10000
# 1  thanh hoa       20000
# 2     france       30000
# 3    vietnam       40000

# %%
example3 = pd.read_csv('StudentsPerformance.csv')
example3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
example3.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows', 10)

# %%
example3.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
example3.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
example3.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001F77F9E7BE0>

# %%
example3.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
example3.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
example3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
len(example3)
# Out:
# 1000

# %%
max(example3.columns)
min(example3.columns)
# Out:
# 'gender'

# %%
type(example3)
# Out:
# pandas.core.frame.DataFrame

# %%
example3['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
example3.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
example3['language']  = 70
example3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
language_score = np.arange(0, 1000)

# %%
example3['language'] = np.random.randint(0,100,size= 1000)

# %%
example3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
so1 = np.random.randint(0,100,size= 1000)

# %%
so2 = np.random.randint(0,100,size= 1000)

# %%
francais = pd.Series(so1, index = np.arange(0, 1000))

# %%
vietnamien = pd.Series(so2, index = np.arange(0, 1000))

# %%
example3.assign(francais = francais, vietnamien = vietnamien)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  ...  reading score  writing score  language  \
# ...

# %%
example3 = example3.assign(francais = francais, vietnamien = vietnamien)

# %%
example3.insert(2, 'que quan', 'thanh hoa')

# %%
example3
# Out:
#      gender race/ethnicity   que quan parental level of education  \
# 0    female        group B  thanh hoa           bachelor's degree
# 1    female        group C  thanh hoa                some college
# 2    female        group B  thanh hoa             master's degree
# 3      male        group A  thanh hoa          associate's degree
# 4      male        group C  thanh hoa                some college
# ..      ...            ...        ...                         ...
# 995  female        group E  thanh hoa             master's degree
# 996    male        group C  thanh hoa                 high school
# 997  female        group C  thanh hoa                 high school
# 998  female        group D  thanh hoa                some college
# 999  female        group D  thanh hoa                some college
#
#             lunch  ... reading score  writing score  language  francais  \
# 0        standard  ...            72             74        14        39
# ...

# %%
example3['francais'].sum()
# Out:
# np.int64(49992)

# %%
example3['vietnamien'].count()
# Out:
# np.int64(1000)

# %%
example3['vietnamien'].mean()
# Out:
# np.float64(48.282)

# %%
example3['vietnamien'].min() / example3['vietnamien'].max()
# Out:
# np.float64(0.0)

# %%
avg = (example3['vietnamien'] + example3['francais'] + example3['language']) / 3

# %%
example3['AVG'] = round(avg,2)

# %%
example3
# Out:
#      gender race/ethnicity   que quan parental level of education  \
# 0    female        group B  thanh hoa           bachelor's degree
# 1    female        group C  thanh hoa                some college
# 2    female        group B  thanh hoa             master's degree
# 3      male        group A  thanh hoa          associate's degree
# 4      male        group C  thanh hoa                some college
# ..      ...            ...        ...                         ...
# 995  female        group E  thanh hoa             master's degree
# 996    male        group C  thanh hoa                 high school
# 997  female        group C  thanh hoa                 high school
# 998  female        group D  thanh hoa                some college
# 999  female        group D  thanh hoa                some college
#
#             lunch  ... writing score  language  francais  vietnamien    AVG
# 0        standard  ...            74        14        39          48  33.67
# ...

# %%
example3['gender'].value_counts(normalize = True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
example3['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
example3.sort_values(['francais' , 'vietnamien'], ascending = False, inplace = True)

# %%
example3.sort_values(['race/ethnicity'], ascending = True, key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity   que quan parental level of education  \
# 14   female        group A  thanh hoa             master's degree
# 77     male        group A  thanh hoa           bachelor's degree
# 428    male        group A  thanh hoa            some high school
# 597    male        group A  thanh hoa            some high school
# 356    male        group A  thanh hoa          associate's degree
# ..      ...            ...        ...                         ...
# 686    male        group E  thanh hoa                some college
# 190  female        group E  thanh hoa          associate's degree
# 995  female        group E  thanh hoa             master's degree
# 608  female        group E  thanh hoa                some college
# 79   female        group E  thanh hoa             master's degree
#
#             lunch  ... writing score  language  francais  vietnamien    AVG
# 14       standard  ...            58        16        62          12  30.00
# ...

# %%
new_index = np.arange(0,1000)

# %%
new_index
import random

# %%
new_index
# Out:
# array([314, 639, 367, 356, 363, 511,  47, 273, 458, 817, 296,  84, 538,
#        832,  61, 634,   2, 299, 380, 524, 539, 654, 186, 399, 627, 880,
#        534, 794, 131, 587, 672, 409, 883, 676, 582, 965, 831, 969,  91,
#        343, 410, 457, 136,  50, 526, 715, 624, 425, 297, 467, 361,  93,
#        103, 116, 377, 184, 919, 128, 866, 653, 890, 476, 109, 197, 208,
#        108, 453, 474, 695, 490, 452, 629, 319, 887, 357, 946, 259, 403,
#        903, 394, 262, 637, 217, 158, 387,  27, 660, 276, 256, 986, 305,
#        881,  88, 791, 757, 202, 764, 200, 340, 183, 180, 998, 995, 440,
#        666, 101, 892, 988, 758, 322, 948, 743, 686, 872, 388, 424, 310,
#        647, 242, 466, 865, 949,  87, 529, 819, 591, 704, 780, 687, 107,
#        265, 973,  71, 849,  79, 138, 768, 829, 770, 523, 950, 588, 480,
#        150, 820, 412, 706, 549, 406, 454, 301, 250,  65, 311, 396, 868,
#        489, 385, 793, 381, 759,  48, 106, 997, 192,  67,  34, 404, 895,
# ...

# %%
random.shuffle(new_index)

# %%
example3['new_index'] = new_index

# %%
example3.set_index('new_index')
example3 = example3.set_index('new_index')

# %%
example3.rename(columns = {'gender' : 'Gender'})
# Out:
#      Gender race/ethnicity   que quan parental level of education  \
# 14   female        group A  thanh hoa             master's degree
# 3      male        group A  thanh hoa          associate's degree
# 994    male        group A  thanh hoa                 high school
# 731    male        group A  thanh hoa            some high school
# 62     male        group A  thanh hoa          associate's degree
# ..      ...            ...        ...                         ...
# 56   female        group E  thanh hoa          associate's degree
# 909    male        group E  thanh hoa           bachelor's degree
# 503  female        group E  thanh hoa          associate's degree
# 538    male        group E  thanh hoa           bachelor's degree
# 79   female        group E  thanh hoa             master's degree
#
#             lunch  ... language  francais  vietnamien    AVG  new_index
# 14       standard  ...       16        62          12  30.00        314
# ...

# %%
example3 = example3.rename(columns = {'gender' : 'Gender'})

# %%
example3 = example3.rename(columns = {'language' : 'english' , 'francais' : 'français'})

# %%
example3 = example3.rename(index = {0 : 'english' , 1 : 'français'})

# %%
example3.set_index('new_index')
example3
# Out:
#      Gender race/ethnicity   que quan parental level of education  \
# 14   female        group A  thanh hoa             master's degree
# 3      male        group A  thanh hoa          associate's degree
# 994    male        group A  thanh hoa                 high school
# 731    male        group A  thanh hoa            some high school
# 62     male        group A  thanh hoa          associate's degree
# ..      ...            ...        ...                         ...
# 56   female        group E  thanh hoa          associate's degree
# 909    male        group E  thanh hoa           bachelor's degree
# 503  female        group E  thanh hoa          associate's degree
# 538    male        group E  thanh hoa           bachelor's degree
# 79   female        group E  thanh hoa             master's degree
#
#             lunch  ... english  français  vietnamien    AVG  new_index
# 14       standard  ...      16        62          12  30.00        314
# ...

# %%
example3.set_index('new_index')
example3 = example3.set_index('new_index')

# %%
example3 =example3.sort_index(ascending = True)

# %%
example3 = example3.rename(index = {0 : 'english' , 1 : 'français'})

# %%
example3
# Out:
#            Gender race/ethnicity   que quan parental level of education  \
# new_index
# english      male        group D  thanh hoa            some high school
# français   female        group B  thanh hoa            some high school
# 2            male        group A  thanh hoa                 high school
# 3          female        group B  thanh hoa           bachelor's degree
# 4          female        group E  thanh hoa          associate's degree
# ...           ...            ...        ...                         ...
# 995          male        group B  thanh hoa                 high school
# 996          male        group C  thanh hoa             master's degree
# 997          male        group B  thanh hoa          associate's degree
# 998        female        group B  thanh hoa           bachelor's degree
# 999          male        group E  thanh hoa            some high school
#
#                   lunch  ... writing score  english  français  vietnamien  \
# ...
