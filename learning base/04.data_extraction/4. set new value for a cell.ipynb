# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %% [markdown]
# # Set value to one cell

# %%
# update L. Messi height
df.loc['L. Messi', 'height_cm'] = 180

# %%
# show dataframe
df.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        180
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %% [markdown]
# # Set value to entire column

# %%
# set height of all players to 190
df.loc[:, 'height_cm'] = 190

# %%
# show dataframe
df.head(3)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 190         72   Argentina         FC Barcelona
# Cristiano Ronaldo        190         83    Portugal             Juventus
# Neymar Jr                190         68      Brazil  Paris Saint-Germain

# %% [markdown]
# # Set value to entire row

# %%
# get all columns that correspond to player ranked last in fifa
df.iloc[-1]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
# set null values to all columns that corresponds to  player ranked last in fifa
import numpy as np
df.iloc[-1, :] = np.nan

# %%
# show dataframe
df.tail(1)
# Out:
#            long_name  age  dob  height_cm  weight_kg nationality club
# short_name
# Pan Ximing       NaN  NaN  NaN        NaN        NaN         NaN  NaN

# %% [markdown]
# # Set value to Multiple cells

# %%
# Set value for all items matching the list of labels
df.loc[['L. Messi', 'Pan Ximing'], ['height_cm']] = 165

# %%
df.tail()
# Out:
#                  long_name   age         dob  height_cm  weight_kg  \
# short_name
# Shao Shuai              邵帅  22.0  1997-03-10      190.0       79.0
# Xiao Mingjie  Mingjie Xiao  22.0  1997-01-01      190.0       66.0
# Zhang Wei               张威  19.0  2000-05-16      190.0       75.0
# Wang Haijian           汪海健  18.0  2000-08-02      190.0       74.0
# Pan Ximing             NaN   NaN         NaN      165.0        NaN
#
#              nationality                           club
# short_name
# Shao Shuai      China PR               Beijing Renhe FC
# Xiao Mingjie    China PR               Shanghai SIPG FC
# Zhang Wei       China PR         Hebei China Fortune FC
# Wang Haijian    China PR  Shanghai Greenland Shenhua FC
# Pan Ximing           NaN                            NaN

# %% [markdown]
# # Set value for rows matching a condition

# %%
# set value for rows matching a condition
list = ['age','dob','height_cm','weight_kg','nationality']
df.loc[df['height_cm'] > 180, list] = 170

# %%
df
# Out:
#                                              long_name    age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  170.0         170
# Neymar Jr                Neymar da Silva Santos Junior  170.0         170
# J. Oblak                                     Jan Oblak  170.0         170
# E. Hazard                                  Eden Hazard  170.0         170
# ...                                                ...    ...         ...
# Shao Shuai                                          邵帅  170.0         170
# Xiao Mingjie                              Mingjie Xiao  170.0         170
# Zhang Wei                                           张威  170.0         170
# Wang Haijian                                       汪海健  170.0         170
# Pan Ximing                                         NaN    NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi               165.0       72.0   Argentina
# Cristiano Ronaldo      170.0      170.0         170
# Neymar Jr              170.0      170.0         170
# J. Oblak               170.0      170.0         170
# E. Hazard              170.0      170.0         170
# ...                      ...        ...         ...
# Shao Shuai             170.0      170.0         170
# Xiao Mingjie           170.0      170.0         170
# Zhang Wei              170.0      170.0         170
# Wang Haijian           170.0      170.0         170
# Pan Ximing             165.0        NaN         NaN
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                                   NaN
#
# [18278 rows x 7 columns]
