# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %% [markdown]
# # copy()

# %% [markdown]
# ## deep = True

# %%
# deep=True by default (Modifications to the data or indices of the copy will not be reflected in the original object )
df_copy = df.copy()

# %%
# update value in original dataframe
df.loc['L. Messi' , 'age'] = 30

# %%
df.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   30  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %%
df_copy.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   35  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %% [markdown]
# ## deep = False

# %%
# deep=False (Any changes to the data of the original will be reflected in the shallow copy and vice versa)
df_copy1 = df.copy(deep = False)

# %%
# update value in original dataframe
df.loc['L. Messi','height_cm'] = 180

# %%
# shallow copy vs original dataframe
df.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   30  1987-06-24        180
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %%
df_copy1.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   30  1987-06-24        180
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %% [markdown]
# ## Simple  assignment

# %%
# make a copy
df_copy2 = df

# %%
# update value in original dataframe
df.loc['L. Messi','height_cm'] = 165

# %%
# copy vs original dataframe
df_copy2.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   30  1987-06-24        165
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %%
df.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   30  1987-06-24        165
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona
