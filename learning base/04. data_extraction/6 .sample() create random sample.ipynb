# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %% [markdown]
# # sample()

# %%
# extract 10 random elements from the "nationality" column
df['nationality'].sample(10, random_state = 35)
# Out:
# short_name
# C. Ninga             Chad
# C. Vargas          Mexico
# D. Hernández       Mexico
# F. Ranocchia        Italy
# C. Villalba     Argentina
# J. Vagnoman       Germany
# B. Espinosa      Colombia
# M. Sepúlveda        Chile
# P. Wiegers        Germany
# Eraso               Spain
# Name: nationality, dtype: object

# %%
# extract a random 20% sample of the dataframe
df.sample(frac = 0.2, random_state = 35)
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# C. Ninga                       Casimir Ninga   26  1993-05-17        186
# C. Vargas       Carlos Alonso Vargas Tenorio   20  1999-02-14        176
# D. Hernández                 Diego Hernández   19  1999-08-13        177
# F. Ranocchia               Filippo Ranocchia   18  2001-05-14        184
# C. Villalba                  Carlos Villalba   20  1998-07-19        175
# ...                                      ...  ...         ...        ...
# Seo Myeong Won                       서명원 徐明原   24  1995-04-19        180
# B. Badibanga                  Beni Badibanga   23  1996-02-19        176
# C. Gentner                 Christian Gentner   33  1985-08-14        189
# K. Iwatake                             岩武 克弥   23  1996-06-04        173
# M. Al Ghamdi                 Majed Al Ghamdi   20  1999-04-07        183
#
#                 weight_kg     nationality                    club
# short_name
# C. Ninga               81            Chad              Angers SCO
# C. Vargas              76          Mexico            Club América
# D. Hernández           77          Mexico    Atlético de San Luis
# F. Ranocchia           76           Italy                 Perugia
# C. Villalba            71       Argentina  Club Atlético Talleres
# ...                   ...             ...                     ...
# Seo Myeong Won         77  Korea Republic              Gangwon FC
# B. Badibanga           71         Belgium        Waasland-Beveren
# C. Gentner             81         Germany      1. FC Union Berlin
# K. Iwatake             70           Japan      Urawa Red Diamonds
# M. Al Ghamdi           70    Saudi Arabia                Al Hazem
#
# [3656 rows x 7 columns]

# %%
# upsample: increase the sampling rate -> frac>1  (Note: replace parameter has to be True for frac parameter > 1)
df.sample(frac = 2, replace = True)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# L. Paredes                Leandro Paredes   25  1994-06-29        180
# J. Dasilva                   Josh Dasilva   20  1998-10-23        185
# L. Ingolotti       Luis Ignacio Ingolotti   19  2000-01-14        180
# M. Al Qahtani          Mishari Al Qahtani   22  1997-04-04        176
# Samuel              Samuel Rosa Gonçalves   28  1991-02-25        185
# ...                                   ...  ...         ...        ...
# A. Poulsen                Andreas Poulsen   19  1999-10-13        188
# O. Niasse      El-Hadji Baye Oumar Niasse   29  1990-04-18        182
# D. Rouyard                   Davy Rouyard   19  1999-08-17        190
# K. Hyland                  Khaleem Hyland   30  1989-06-05        183
# M. Ezzarfani            Mohamed Ezzarfani   21  1997-11-15        176
#
#                weight_kg        nationality                      club
# short_name
# L. Paredes            75          Argentina       Paris Saint-Germain
# J. Dasilva            75            England                 Brentford
# L. Ingolotti          78          Argentina    Club Atlético Aldosivi
# M. Al Qahtani         64       Saudi Arabia                  Al Wehda
# Samuel                83             Brazil    Jeonbuk Hyundai Motors
# ...                  ...                ...                       ...
# A. Poulsen            80            Denmark  Borussia Mönchengladbach
# O. Niasse             82            Senegal                   Everton
# D. Rouyard            74             France  FC Girondins de Bordeaux
# K. Hyland             80  Trinidad & Tobago                Al Faisaly
# M. Ezzarfani          70            Morocco              RCD Espanyol
#
# [36556 rows x 7 columns]
